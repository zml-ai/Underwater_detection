# %%
from ensemble_boxes import *
import json
import cv2
import matplotlib.pyplot as plt
from tqdm import tqdm

# %%
json1_path = r'/media/alvinai/Documents/underwater/ahf_work_dirs/ensemble/nms/base模型带海草加albu_次模型不带海草加albu_均拆分数据集训练/x101valsoftnmsresult_epoch_12.json.bbox.json.json' # 模型1结果文件路径
json2_path = r'/media/alvinai/Documents/underwater/ahf_work_dirs/ensemble/nms/base模型带海草加albu_次模型不带海草加albu_均拆分数据集训练/s50seval_softnms_epoch_12.bbox.json' # 模型2结果文件路径
test_path = r'/media/alvinai/Documents/underwater/data/seacoco/val_new.json' # 测试集标注路径
save_path = r'/media/alvinai/Documents/underwater/ahf_work_dirs/ensemble/nms/base模型带海草加albu_次模型不带海草加albu_均拆分数据集训练/linearsoftnms_iou05_ensemble_x101_s50_val.bbox.json' # 融合结果保存路径

# %%
with open(json1_path, 'r') as f1:
    json1 = json.load(f1)

with open(json2_path, 'r') as f2:
    json2 = json.load(f2)
    
with open(test_path, 'r') as f3:
    test = json.load(f3)

# %% [markdown]
# ### 观察预测结果的内容

# %%
print(test['categories'])
print(json1[0])
print(json2[0])
print("="*20)
print("the number of annotations from json1:", len(json1))
cat_dict = {}
for i in range(1,6):
    if i not in list(cat_dict.keys()):
        cat_dict[i] = 0
for a in json1:
    cat_dict[a['category_id']]+=1
print(cat_dict)
print("="*20)
print("the number of annotations from json2:", len(json2))
cat_dict = {}
for i in range(1,6):
    if i not in list(cat_dict.keys()):
        cat_dict[i] = 0
for a in json2:
    cat_dict[a['category_id']]+=1
print(cat_dict)
# Out:
# [{'supercategory': 'holothurian', 'id': 1, 'name': 'holothurian'}, {'supercategory': 'echinus', 'id': 2, 'name': 'echinus'}, {'supercategory': 'scallop', 'id': 3, 'name': 'scallop'}, {'supercategory': 'starfish', 'id': 4, 'name': 'starfish'}]
# {'image_id': 1, 'bbox': [695.4244384765625, 408.534423828125, 136.5372314453125, 163.5576171875], 'score': 0.995360255241394, 'category_id': 1}
# {'image_id': 1, 'bbox': [696.0093994140625, 410.30303955078125, 134.08404541015625, 150.13970947265625], 'score': 0.9711553454399109, 'category_id': 1}
# ====================
# the number of annotations from json1: 186372
# {1: 51018, 2: 41071, 3: 35657, 4: 36750, 5: 21876}
# ====================
# the number of annotations from json2: 130714
# {1: 44538, 2: 31865, 3: 27443, 4: 26868, 5: 0}

# %% [markdown]
# ### 去除预测文件中的海草

# %%
json1_new = []
json2_new = []

def remove_waterweeds(old_json, new_json):
    """去除海草"""
    for a in old_json:
        if a['category_id'] != 5:
            new_json.append(a)

remove_waterweeds(json1, json1_new)
remove_waterweeds(json2, json2_new)
print('After removing waterweeds:')
print("the number of annotations from json1:", len(json1_new))
print("the number of annotations from json2:", len(json2_new))
json1 = json1_new
json2 = json2_new
# Out:
# After removing waterweeds:
# the number of annotations from json1: 164496
# the number of annotations from json2: 130714

# %% [markdown]
# ### 定义单张图上的结果融合操作

# %%
def wbf(iou_thr, imgid, test, weights, skip_box_thr, conf_type):
    """对单张图上多个模型的结果进行融合
    参数：
        1. iou_thr(float)  : 设IOU多少才能实现boxes匹配，论文推荐0.55。
        2. imgid(int)      : 输入单张图片的image id。
        3. test(dict)      ：test.json文件的内容。
        4. weights(list)   : 给予分别给两个模型结果的权重，默认为[2, 1]，即模型1的box的权重为2，模型2的权重为1。
        5. skip_box_thr(float): 不对置信度小于kip_box_thr的框进行WBF。
        6. conf_type(str)  : 对于聚类匹配框的置信度采用的融合模式，‘avg'/’max‘。
    返回：
        1. boxes(list)     ：WBF融合后的框(从normalization恢复)，[x1, y1, w, h]。
        2. socres(list)    : WBF融合后的分数。
        3. labels(list)    : WBF融合后的标签。
    """
    # 获取该图的宽高
    imgw = None
    imgh = None
    for i in test['images']:
        if i['id'] == imgid:
            imgw = i['width']
            imgh = i['height']
            break
    
    # 用宽高normalize标注框
    boxes_list1 = []
    scores_list1 = []
    labels_list1 = []
    for a in json1:
        if a['image_id'] == imgid:
            bbox_x1 = float(a['bbox'][0] / imgw)
            bbox_y1 = float(a['bbox'][1] / imgh)
            bbox_x2 = float((a['bbox'][0] + a['bbox'][2] - 1) / imgw)
            bbox_y2 = float((a['bbox'][1] + a['bbox'][3] - 1) / imgh)
            boxes_list1.append([bbox_x1, bbox_y1, bbox_x2, bbox_y2])
            scores_list1.append(a['score'])
            labels_list1.append(a['category_id'])
            
    boxes_list2 = []
    scores_list2 = []
    labels_list2 = []
    for a in json2:
        if a['image_id'] == imgid:
            bbox_x1 = float(a['bbox'][0] / imgw)
            bbox_y1 = float(a['bbox'][1] / imgh)
            bbox_x2 = float((a['bbox'][0] + a['bbox'][2] - 1) / imgw)
            bbox_y2 = float((a['bbox'][1] + a['bbox'][3] - 1) / imgh)
            boxes_list2.append([bbox_x1, bbox_y1, bbox_x2, bbox_y2])
            scores_list2.append(a['score'])
            labels_list2.append(a['category_id'])            
            
    # 合并结果
    boxes_list = [boxes_list1, boxes_list2]
    scores_list = [scores_list1, scores_list2]
    labels_list = [labels_list1, labels_list2]
    
    # 实现weight boxes fusion
    # method: 1 - linear soft-NMS, 2 - gaussian soft-NMS, 3 - standard NMS
    boxes, scores, labels = nms_method(boxes_list, scores_list, labels_list,
                                       method=1, 
                                       weights=weights, iou_thr=iou_thr, sigma=0.5, thresh=0.001)
    # 还原normalized的bbox
    new_boxes = []
    for i, box in enumerate(boxes):
        box_x1 = float(box[0] * imgw)
        box_y1 = float(box[1] * imgh)
        box_w = float((box[2] - box[0]) * imgw)
        box_h = float((box[3] - box[1]) * imgh)
        new_boxes.append([box_x1, box_y1, box_w, box_h])
    return new_boxes, list(scores), list(labels)

# %% [markdown]
# ### 批量对所有图的结果进行WBF

# %%
# 得到所有image_id
imgids = []
for r in test['images']:
    if r['id'] not in imgids:
        imgids.append(r['id'])
print("There are %d unique image id" % len(imgids))
# Out:
# There are 924 unique image id

# %%
iou_thr = 0.5
weights = [1, 1]
skip_box_thr = 0.0
conf_type = 'avg'

new_result = []
#  91%|█████████ | 838/924 [00:58<00:05, 16.15it/s]
#  91%|█████████ | 840/924 [00:59<00:05, 14.43it/s]
#  91%|█████████ | 842/924 [00:59<00:05, 14.62it/s]
#  91%|█████████▏| 844/924 [00:59<00:05, 15.16it/s]
#  92%|█████████▏| 847/924 [00:59<00:04, 17.26it/s]
#  92%|█████████▏| 850/924 [00:59<00:04, 18.41it/s]
#  92%|█████████▏| 852/924 [00:59<00:04, 14.99it/s]
#  92%|█████████▏| 854/924 [01:00<00:04, 14.17it/s]
#  93%|█████████▎| 856/924 [01:00<00:04, 14.96it/s]
#  93%|█████████▎| 858/924 [01:00<00:04, 15.16it/s]
#  93%|█████████▎| 860/924 [01:00<00:04, 15.26it/s]
#  93%|█████████▎| 862/924 [01:00<00:03, 15.87it/s]
#  94%|█████████▎| 864/924 [01:00<00:04, 14.67it/s]
#  94%|█████████▎| 866/924 [01:00<00:04, 13.38it/s]
#  94%|█████████▍| 868/924 [01:01<00:05, 11.03it/s]
#  94%|█████████▍| 871/924 [01:01<00:04, 12.18it/s]
#  94%|█████████▍| 873/924 [01:01<00:04, 12.38it/s]
#  95%|█████████▍| 876/924 [01:01<00:03, 14.24it/s]
#  95%|█████████▌| 878/924 [01:01<00:03, 13.07it/s]
#  95%|█████████▌| 880/924 [01:01<00:03, 12.58it/s]
#  95%|█████████▌| 882/924 [01:02<00:02, 14.04it/s]
#  96%|█████████▌| 884/924 [01:02<00:02, 14.80it/s]
#  96%|█████████▌| 886/924 [01:02<00:02, 14.16it/s]
#  96%|█████████▌| 888/924 [01:02<00:02, 13.33it/s]
#  96%|█████████▋| 890/924 [01:02<00:02, 14.41it/s]
#  97%|█████████▋| 892/924 [01:02<00:02, 14.72it/s]
#  97%|█████████▋| 894/924 [01:02<00:02, 12.94it/s]
#  97%|█████████▋| 896/924 [01:03<00:02, 13.41it/s]
#  97%|█████████▋| 898/924 [01:03<00:01, 13.65it/s]
#  97%|█████████▋| 900/924 [01:03<00:01, 14.11it/s]
#  98%|█████████▊| 902/924 [01:03<00:01, 13.69it/s]
#  98%|█████████▊| 904/924 [01:03<00:01, 12.46it/s]
#  98%|█████████▊| 906/924 [01:03<00:01, 10.46it/s]
#  98%|█████████▊| 909/924 [01:04<00:01, 12.83it/s]
#  99%|█████████▊| 911/924 [01:04<00:00, 13.45it/s]
#  99%|█████████▉| 913/924 [01:04<00:00, 14.19it/s]
#  99%|█████████▉| 916/924 [01:04<00:00, 14.59it/s]
#  99%|█████████▉| 918/924 [01:04<00:00, 15.76it/s]
# 100%|█████████▉| 920/924 [01:04<00:00, 14.91it/s]
# 100%|█████████▉| 923/924 [01:04<00:00, 17.02it/s]
# 100%|██████████| 924/924 [01:05<00:00, 14.21it/s]

# %%
cat_dict = {}
for i in range(1,5):
    if i not in list(cat_dict.keys()):
        cat_dict[i] = 0
for a in new_result:
    cat_dict[a['category_id']]+=1
print(cat_dict)
# Out:
# {1: 66825, 2: 50348, 3: 43114, 4: 44736}

# %%
test['images'][-1]
# Out:
# {'file_name': '005539.jpg', 'height': 1080, 'width': 1920, 'id': 5539}

# %%
new_result[-1]
# Out:
# {'image_id': 5539,
#  'bbox': [519.8178100585938,
#   1024.3021240234375,
#   36.76495361328133,
#   37.29589843750008],
#  'score': 5.1755818276433274e-05,
#  'category_id': 2}

# %%
print('After WBF:')
print("the number of annotation result:", len(new_result))
# Out:
# After WBF:
# the number of annotation result: 205023

# %% [markdown]
# ### 可视化结果（Debug用）

# %%
# 可视化模型1的结果
fig = plt.figure(figsize=(16,16))
img_path = r'/media/alvinai/Documents/underwater/data/seacoco/val/005539.jpg'
img = cv2.imread(img_path)
for a in json1:
    if a['image_id'] == 5539 and a['score']>=0.05:
        boxes = a['bbox']
        img = cv2.rectangle(img, (int(boxes[0]), int(boxes[1])),
                            (int(boxes[0]+boxes[2]), int(boxes[1]+boxes[3])), (255,0,0), 8)
        for cat in test['categories']:
            if cat['id'] == a['category_id']:
                catname = cat['name']
                break
        txt = catname + str(round(a['score'],1))
        img = cv2.putText(img, txt, (int(boxes[0]), int(boxes[1])), cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 0, 0), 4)
plt.imshow(img[:,:,::-1])
plt.show()

# %%
# 可视化模型2的结果
fig = plt.figure(figsize=(16,16))
img_path = r'/media/alvinai/Documents/underwater/data/seacoco/val/005539.jpg'
img = cv2.imread(img_path)
for a in json2:
    if a['image_id'] == 5539 and a['score']>=0.05:
        boxes = a['bbox']
        img = cv2.rectangle(img, (int(boxes[0]), int(boxes[1])),
                            (int(boxes[0]+boxes[2]), int(boxes[1]+boxes[3])), (255,0,0), 8)
        for cat in test['categories']:
            if cat['id'] == a['category_id']:
                catname = cat['name']
                break
        txt = catname + str(round(a['score'],1))
        img = cv2.putText(img, txt, (int(boxes[0]), int(boxes[1])), cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 0, 0), 4)
plt.imshow(img[:,:,::-1])
plt.show()

# %%
# 可视化模型2的结果
fig = plt.figure(figsize=(16,16))
img_path = r'/media/alvinai/Documents/underwater/data/seacoco/val/005539.jpg'
img = cv2.imread(img_path)
for a in new_result:
    if a['image_id'] == 5539 and a['score']>=0.05:
        boxes = a['bbox']
        img = cv2.rectangle(img, (int(boxes[0]), int(boxes[1])),
                            (int(boxes[0]+boxes[2]), int(boxes[1]+boxes[3])), (255,0,0), 8)
        for cat in test['categories']:
            if cat['id'] == a['category_id']:
                catname = cat['name']
                break
        txt = catname + str(round(a['score'],1))
        img = cv2.putText(img, txt, (int(boxes[0]), int(boxes[1])), cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 0, 0), 4)
plt.imshow(img[:,:,::-1])
plt.show()

# %%
json_final = []
for a in json1:
    if a['category_id'] != 1:
        json_final.append(a)
for a in new_result:
    if a['category_id'] == 1:
        json_final.append(a)

cat_dict = {}
for i in range(1,5):
    if i not in list(cat_dict.keys()):
        cat_dict[i] = 0
for a in json_final:
    cat_dict[a['category_id']]+=1
print(cat_dict)
# Out:
# {1: 120847, 2: 64597, 3: 69668, 4: 51414}

# %%
with open(save_path, 'w') as f5:
    json.dump(json_final, f5)
